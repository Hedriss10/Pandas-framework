# %% [markdown]
# #### Dados faltantes para extração de data science

# %%
import pandas as pd

# %%
dados = pd.read_csv('/home/hedris/Área de Trabalho/Pandas-framework/base/imoveis_residencial.csv', sep=';')

# %%
dados.head(5)
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# 4         NaN   NaN

# %% [markdown]
# #### transformando o dataset em booleano para vê e analisar de uma forma mais intriga

# %%
# insull gerar true ou false sobre o data frame
dados.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False   True
# 4      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 23141  False   False    False  False   False  False  False       False  False
# 23142  False   False    False  False   False  False  False       False  False
# 23143  False   False    False  False   False  False  False       False  False
# 23144  False   False    False  False   False  False  False       False  False
# 23145  False   False    False  False   False  False  False       False   True
#
# [23146 rows x 9 columns]

# %%
# ele vai fazer o contrario do insull se a info for falsa ele passa como true
dados.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio   IPTU
# 0      True    True     True   True    True  True   True        True   True
# 1      True    True     True   True    True  True   True       False  False
# 2      True    True     True   True    True  True   True        True   True
# 3      True    True     True   True    True  True   True        True  False
# 4      True    True     True   True    True  True   True       False  False
# ...     ...     ...      ...    ...     ...   ...    ...         ...    ...
# 23141  True    True     True   True    True  True   True        True   True
# 23142  True    True     True   True    True  True   True        True   True
# 23143  True    True     True   True    True  True   True        True   True
# 23144  True    True     True   True    True  True   True        True   True
# 23145  True    True     True   True    True  True   True        True  False
#
# [23146 rows x 9 columns]

# %%
# informçaõ do dataframe 
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23146 entries, 0 to 23145
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        23146 non-null  object
#  1   Bairro      23146 non-null  object
#  2   Quartos     23146 non-null  int64
#  3   Vagas       23146 non-null  int64
#  4   Suites      23146 non-null  int64
#  5   Area        23146 non-null  int64
#  6   Valor       23137 non-null  float64
#  7   Condominio  20824 non-null  float64
#  8   IPTU        16154 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
dados[dados["Valor"].isnull()]
# Out:
#              Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 59    Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 1525  Apartamento             Leme        2      0       0    75    NaN
# 1720         Casa     Campo Grande        3      4       3   363    NaN
# 2053  Apartamento         Botafogo        2      0       0    95    NaN
# 2075  Apartamento       Copacabana        2      0       0    72    NaN
# 5054         Casa     Campo Grande        3      2       1   100    NaN
# 8774  Apartamento             Leme        2      0       1    75    NaN
# 9169  Apartamento           Glória        3      0       1   135    NaN
# 9373  Apartamento            Gávea        3      1       1   105    NaN
#
#       Condominio   IPTU
# 59         970.0   68.0
# 1525       878.0    NaN
# 1720         NaN    NaN
# 2053      1010.0  170.0
# 2075       850.0    NaN
# 5054         NaN    NaN
# 8774       878.0    NaN
# 9169       910.0  228.0
# ...

# %%
a = dados.shape[0]
dados.dropna(subset = ["Valor"], inplace=True)
b = dados.shape[0]
a - b
# Out:
# 0

# %%
dados[dados["Valor"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ##### Tratamento de dados faltantes (continuação)

# %%
# nam => True 
dados[dados["Condominio"].isnull()].shape[0]
# Out:
# 2320

# %%
selecao =  (dados["Tipo"] == "Apartamento") & (dados['Condominio'].isnull())

# %%
a = dados.shape[0]
dados = dados[~selecao]
b = dados.shape[0]
a-b
# Out:
# /tmp/ipykernel_44556/71841567.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dados = dados[~selecao]
# 0

# %%
dados[dados["Condominio"].isnull()].shape[0]
# Out:
# 1575

# %%
dados.fillna(0, inplace=True)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 23141  Apartamento                 Méier        2      0       0    70
# 23142    Quitinete                Centro        0      0       0    27
# 23143  Apartamento           Jacarepaguá        3      1       2    78
# 23144  Apartamento  São Francisco Xavier        2      1       0    48
# 23145  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %%
dados.to_csv('/home/hedris/Área de Trabalho/Pandas-framework/base/imoveis_residencial.csv', sep=';', index=False)

# %%
df = pd.read_csv('/home/hedris/Área de Trabalho/Pandas-framework/base/imoveis_residencial.csv', sep=';')
df.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU
# 0   1700.0       500.0  60.0
# 1   7000.0         0.0   0.0
# 2    800.0       390.0  20.0
# 3    800.0       230.0   0.0
# ...
